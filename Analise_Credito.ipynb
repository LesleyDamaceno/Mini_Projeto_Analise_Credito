# %% [markdown]
# <a href="https://colab.research.google.com/github/LesleyDamaceno/Mini_Projeto_Analise_Credito/blob/main/Analise_Credito.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
import pandas as pd
df = pd.read_csv ('clientes_exemplo.csv')
df.head ()
# Out:
#      <input type="file" id="files-779e3c38-7840-4742-a016-e25e88d2c8df" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-779e3c38-7840-4742-a016-e25e88d2c8df">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id_cliente     10 non-null     int64
#  1   nome           10 non-null     object
#  2   idade          10 non-null     int64
#  3   risco          10 non-null     object
#  4   valor_credito  10 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 532.0+ bytes

# %%
df.describe ()
# Out:
#        id_cliente      idade  valor_credito
# count    10.00000  10.000000      10.000000
# mean      5.50000  38.200000    3980.000000
# std       3.02765  11.961048    1868.927203
# min       1.00000  22.000000    1500.000000
# 25%       3.25000  29.750000    2575.000000
# 50%       5.50000  38.000000    3750.000000
# 75%       7.75000  44.000000    5375.000000
# max      10.00000  60.000000    7000.000000

# %%
df['faixa etária'] = pd.cut(df['idade'],
                            bins=[18, 30, 45, 60, 100],
                            labels=['18-30', '31-45', '46-60', '60+'])
df.head()
# Out:
#    id_cliente    nome  idade risco  valor_credito faixa etária
# 0           1     Ana     25   bom           2000        18-30
# 1           2   Bruno     32  ruim           5000        31-45
# 2           3   Carla     40   bom           3000        31-45
# 3           4  Daniel     22   bom           1500        18-30
# 4           5  Elaine     36  ruim           4500        31-45

# %%
df['risco'].value_counts()
# Out:
# risco
# bom     5
# ruim    5
# Name: count, dtype: int64

# %%
df.groupby('risco')['valor_credito'].mean()
# Out:
# risco
# bom     2360.0
# ruim    5600.0
# Name: valor_credito, dtype: float64

# %%
df.to_csv('clientes_tratado.csv', index=False)
from google.colab import files
files.download('clientes_tratado.csv')
